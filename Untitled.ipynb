# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('datasets_13720_18513_insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.pairplot(df)

# %%
sns.distplot(df['charges'])

# %%
sns.heatmap(df.corr(),annot=True)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.get_dummies(df, columns=["sex"], prefix=["sex_is"] )
df.head()
# Out:
#    age     bmi  children smoker     region      charges  sex_is_female  \
# 0   19  27.900         0    yes  southwest  16884.92400              1
# 1   18  33.770         1     no  southeast   1725.55230              0
# 2   28  33.000         3     no  southeast   4449.46200              0
# 3   33  22.705         0     no  northwest  21984.47061              0
# 4   32  28.880         0     no  northwest   3866.85520              0
#
#    sex_is_male
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df = pd.get_dummies(df, columns=["smoker"], prefix=["smoker?_"] )
df.head()
# Out:
#    age     bmi  children     region      charges  sex_is_female  sex_is_male  \
# 0   19  27.900         0  southwest  16884.92400              1            0
# 1   18  33.770         1  southeast   1725.55230              0            1
# 2   28  33.000         3  southeast   4449.46200              0            1
# 3   33  22.705         0  northwest  21984.47061              0            1
# 4   32  28.880         0  northwest   3866.85520              0            1
#
#    smoker?__no  smoker?__yes
# 0            0             1
# 1            1             0
# 2            1             0
# 3            1             0
# 4            1             0

# %%
df['region'] = df['region'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1338 non-null   int64
#  1   bmi            1338 non-null   float64
#  2   children       1338 non-null   int64
#  3   region         1338 non-null   category
#  4   charges        1338 non-null   float64
#  5   sex_is_female  1338 non-null   uint8
#  6   sex_is_male    1338 non-null   uint8
#  7   smoker?__no    1338 non-null   uint8
#  8   smoker?__yes   1338 non-null   uint8
# dtypes: category(1), float64(2), int64(2), uint8(4)
# memory usage: 48.7 KB

# %%
df.columns
# Out:
# Index(['age', 'bmi', 'children', 'region', 'charges', 'sex_is_female',
#        'sex_is_male', 'smoker?__no', 'smoker?__yes'],
#       dtype='object')

# %%
for x in ['age', 'bmi', 'children']:
    sns.lmplot(x=x, y='charges',data=df)

# %% [markdown]
# ## Training and tes
